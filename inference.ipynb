# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/stroma\ nutsbolts/yolov7
# Out:
# /content/drive/MyDrive/stroma nutsbolts/yolov7

# %% [markdown]
# Inference on test.mp4

# %%
# !python detect.py --weights runs/train/yolov7-nutsbolts2/weights/best.pt --conf 0.7 --img-size 640 --source test.mp4 --no-trace

# %% [markdown]
# Below script is for visualisation, it shows previously recorded test output as mp4. The script is obtained from https://stackoverflow.com/a/57378660

# %%
from IPython.display import HTML
from base64 import b64encode

mp4 = open("./runs/detect/exp3/test.mp4",'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=640 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video width=640 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>
